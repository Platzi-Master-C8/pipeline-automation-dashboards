# %%
# !pip install dnspython
# !pip install pymongo
# !pip install "pymongo[srv]"
# Out:
# ...
#      |████████████████████████████████| 266 kB 5.0 MB/s
# ...

# %%
from pymongo import MongoClient

# %%
host = 'cluster0.4k2av.mongodb.net/myFirstDatabase?retryWrites=true&w=majority'
user = 'automation'
password = 'frnNbMpc1nweJBmZ'
database = 'webmaker'
cliente = MongoClient("mongodb+srv://{}:{}@{}".format(user, password, host))

# %%
cliente[database].templates.find()
